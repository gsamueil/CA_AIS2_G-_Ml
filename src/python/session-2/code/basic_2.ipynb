# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
list_1 = [1,2,3,4,"Depi", "learning",True,[1,2,3,["ML", "AI","GenAI"]]]

# %%
x = "george"

# %%
list_1 = ["Depi","learning","ml"]
list_1.append("GenAi")

# %%
list_1 = ["Depi","learning","ml"]
list_1.insert(1,"Deep learning")
list_1
# Out:
# ['Depi', 'Deep learning', 'learning', 'ml']

# %%
list_1 = ["Depi","learning","ml"]
list_2 = ["NTI","learning","GenAi"]
x = list_1 + list_2
print(x)
print(list_1)
# Out:
# ['Depi', 'learning', 'ml', 'NTI', 'learning', 'GenAi']
# ['Depi', 'learning', 'ml']

# %%
x = "depi"
x[3]
# Out:
# 'i'

# %%
list_1 = ["Depi","learning","ml"]
list_2 = ["NTI","learning","GenAi"]
list_1.extend("george")
list_1
# Out:
# ['Depi', 'learning', 'ml', 'g', 'e', 'o', 'r', 'g', 'e']

# %%
list_1 = ["Depi","learning","ml","learning"]
list_1.remove("learning")
list_1
# Out:
# ['Depi', 'ml', 'learning']

# %%
list_1 = ["Depi","learning","ml",1]
x = list_1.pop()
print(x)
print(type(x))
# Out:
# 1
# <class 'int'>

# %%
list_1
# Out:
# ['Depi', 'learning', 'ml']

# %%
del list_1

# %%
name = input("enter you name  ")
id = input("enter your id")
print(name, id)
# Out:
# 10 10

# %%
list_1 = ["Depi","learning","ml","learning"]
item = input("enter item")

list_1.remove(item)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       1 list_1 = ["Depi","learning","ml","learning"]
#       2 item = input("enter item")
#       3
# ----> 4 list_1.remove(item)
#
# ValueError: list.remove(x): x not in list

# %%
list_1 = [30,10,5,18,20]

# %%
x = list_1.sort()
print(list_1)
print(x)
# Out:
# [5, 10, 18, 20, 30]
# None

# %%
list_2 = [30,10,5,18,35]
x = sorted(list_2)
print(list_2)
print(x)
# Out:
# [30, 10, 5, 18, 35]
# [5, 10, 18, 30, 35]

# %%
list_3 = [1,2,3]
list_3.reverse()

# %%
list_3
# Out:
# [3, 2, 1]

# %%
input = "ml"
tup_1 = ("Depi","learning","ml","learning")
new_list_of_tuple = list(tup_1)
new_list_of_tuple.remove("ml")
tuple(new_list_of_tuple)
# Out:
# ('Depi', 'learning', 'learning')

# %%
set1 = {1,2,3}
set2 = {3,4,5}
print(set1.difference(set2)) # unoin
# Out:
# {1, 2}

# %%
dict_one = {"k1":10.5,"k2":"Depi","k3":"python", 20:[1,2,2,4,5]}
dict_one["k1"] = "ai engineer"
dict_one
# Out:
# {'k1': 'ai engineer', 'k2': 'Depi', 'k3': 'python', 20: [1, 2, 2, 4, 5]}

# %%
input("")

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
==
# Out:
# 1

# %%
__eq__(a, b)

# %%
num1 = float(input("enter the first num"))
num2 = float(input("enter the second num"))

print(f"first num {num1} + second num {num2} = ", num1 + num2)
# Out:
# first num 30.0 + second num 50.0 =  80.0

# %%
a = 200
b = 33
if b >a :
    print("b is greater than a")
elif b ==  a :
    print("b is greater than a")
elif b != a :
    print("b is greater than a")

else:
    print("b is not greater than a ")
# Out:
# b is not greater than a

# %%
x = 5 
result = "even"  if x % 2 == 0 else "odd"

# %%
a = 10
b = 5
result = a +b if a>b else a-b
print(result)
# Out:
# 15

# %%
is_sunny = True
temperature = 25

if is_sunny:
    print("Its a sunny day!")
    
    if temperature >20:
        print("the weather is warm")
    else:
        print("the weather is cool")
else:
    print("Its not sunny day.")

# %%
score = float(input("enter your degree"))
if   0<= score  <=100:
    if 90<= score <=100:
        grade ="A"
    elif:
        pass
    elif:
        pass
else

# %%
for i in "depi":
    print(i)
# Out:
# d
# e
# p
# i

# %%
for i in range(6):
    if i == 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
def sum(x,y):
    ...
