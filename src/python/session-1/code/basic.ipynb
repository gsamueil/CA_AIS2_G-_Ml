# %%
x  = 10
hex(id(x))
# Out:
# '0x7fff3233ead8'

# %%
abs(-5)
# Out:
# 5

# %%
name = "mina"
age = 30
print("my name is {} and my age is {}".format(name, age))
# Out:
# my name is mina and my age is 30

# %%
print(f"my name is {name} and my age is {age}")
# Out:
# my name is mina and my age is 30

# %%
name =
age = 
course = 
print(f"")

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
lst_1 = [1,2,3,4,5]
print(type(lst_1))
# Out:
# <class 'list'>

# %%
tup_1 = (1,2)
print(id(tup_1))
print(type(tup_1))
tup_1 = (3,4)
id(tup_1)
# Out:
# 1964370787840
# <class 'tuple'>
# 1964370808320

# %%
tup_1 = [2,5]
tup_1[0] = 200

# %%
lst_to_tup =tuple(tup_1)
print(type(lst_to_tup))
# Out:
# <class 'tuple'>

# %%
set_1 = {1,2,3}
print(type(set_1))
set
# Out:
# <class 'set'>

# %%
dict_1 = {'k1':30,'k2':30}
print((dict_1.keys()))
dict
# Out:
# dict_keys(['k1', 'k2'])
# dict

# %%
x = "depi for machine learning"
print(x[::])
type(x)
# Out:
# depi for machine learning
# str

# %%
name = "Depi for machine learning for everyone"
capital = name.upper()
capital.lower()
# Out:
# 'depi for machine learning for everyone'

# %%
name = "depi learning"
name.replace("depi", "machine")
# Out:
# 'machine learning'

# %%
name = "depi for ai"
name.capitalize()
# Out:
# 'Depi for ai'

# %%
name = "depi for everyone"
name.title()
# Out:
# 'Depi For Everyone'

# %%
name = "depi for machine learning and depi for genai"
name.endswith("depi")
# Out:
# False

# %%
name = "depi for machine learning and depi for genai"
x = name.split()
type(x)
# Out:
# list

# %%
x
# Out:
# ['depi', 'for', 'machine', 'learning', 'and', 'depi', 'for', 'genai']

# %%
new_x = ' '.join(x)

# %%
new_x
# Out:
# 'depi for machine learning and depi for genai'

# %%
print("hello world for \"students\" in depi")
# Out:
# hello world for "students" in depi

# %%
print("hello world for\b students in depi")
# Out:
# hello world fo students in depi
