# %%
print("hello")
# Out:
# hello

# %%
age = 40
print("my name is george and my age is ", age)
# Out:
# my name is george and my age is  40

# %%
x = 10
hex(id(x))
# Out:
# '0x7fff3233ead8'

# %%
abs(-5)
# Out:
# 5

# %%
x = 88 #this variable is int 
# ================================
x ='''  
this app help user to find anything
dklfjdkjflkdsjfkldsjfjdsklfjd

kjfdkljflkdj

fdskjf
'''
x
# Out:
# '  \nthis app help user to find anything\ndklfjdkjflkdsjfkldsjfjdsklfjd\n\nkjfdkljflkdj\n\nfdskjf\n'

# %%
x = 10

print(type(x))
# Out:
# <class 'int'>

# %%
name = "george"
age = 40

print("my name is {1} and age is {0}".format(name, age))
# Out:
# my name is 40 and age is george

# %%
print(f"my name is {name} and my age is {age}")
# Out:
# my name is george and my age is 40

# %%
name = 
age = 
course_name= 
output = f"ArithmeticError"
print(output)

# %%
x = [1,2,2.2,4,"hi",[11,22,33]]
x[0] = 100
print(x[0])
print(type(x))
# Out:
# 100
# <class 'list'>

# %%
t = (1,2,2.2,4,"hi",[11,22,33])
t[0] = 100
print(x[0])
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 2
#       1 t = (1,2,2.2,4,"hi",[11,22,33])
# ----> 2 t[0] = 100
#       3 print(x[0])
#       4 print(type(x))
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup1 = (2,1)
print(type(tup1))
# Out:
# <class 'tuple'>

# %%
s = {1,2,3}
print(type(s))
# Out:
# <class 'set'>

# %%
dic1 = {"k1":20,'k2':20}

# %%
name = "depi for everyone"

name[5 :  8  : 1]
# Out:
# 'for'

# %%
name = "depi for machine learning"

# %%
capital = name.upper()
capital
# Out:
# 'DEPI FOR MACHINE LEARNING'

# %%
capital.lower()
# Out:
# 'depi for machine learning'

# %%
name = "depi for machine learning and depi for genai"
name.replace("machine", "deep ")
# Out:
# 'depi for deep  learning and depi for genai'

# %%
name.capitalize()
# Out:
# 'Depi for machine learning and depi for genai'

# %%
name.title()
# Out:
# 'Depi For Machine Learning And Depi For Genai'

# %%
name.count("depi")
# Out:
# 2

# %%
x = name.split()
x
# Out:
# ['depi', 'for', 'machine', 'learning', 'and', 'depi', 'for', 'genai']

# %%
new_x = ' '.join(x)
new_x
# type(new_x)
# Out:
# 'depi for machine learning and depi for genai'

# %%
name.start

# %%
print("hello \"depi\" and\b nti ")
# Out:
# hello "depi" an nti
